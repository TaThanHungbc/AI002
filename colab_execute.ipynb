# %%
import os

# Replace 'YOUR_REPOSITORY_URL' with the actual URL of the GitHub repository
# For example: !git clone https://github.com/user/repo.git
# !git clone https://github.com/TaThanHungbc/AI002

# After cloning, you might want to list the contents of the current directory
# to see the cloned repository.
# !ls

# %%
# Chuyển vào thư mục AI002
# %cd AI002

# Kiểm tra nếu file requirements.txt tồn tại và cài đặt các thư viện
import os
if os.path.exists('requirements.txt'):
    # !pip install -r requirements.txt
else:
    print("Không tìm thấy 'requirements.txt'. Bạn có thể cần cài đặt các thư viện thủ công hoặc chạy file chính và cài đặt theo lỗi.")

# Trở lại thư mục gốc sau khi kiểm tra/cài đặt
# %cd ..

# %%
# Chuyển vào thư mục AI002 để chạy main.py
# %cd AI002

# Chạy file main.py để train model
# Thay thế hoặc thêm các đối số cần thiết nếu project của bạn yêu cầu.
# !python main.py --epochs 20 --batch_size 16 --num_workers 2

# Sau khi hoàn thành, trở lại thư mục gốc của Colab
# %cd ..
